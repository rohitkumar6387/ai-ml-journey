# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
import pandas as pd

# %%
nova_df=pd.read_csv("novagen_dataset.csv")

# %%
nova_df.head()
# Out:
#     Age   BMI  Blood_Pressure  Cholesterol  Glucose_Level  Heart_Rate  \
# 0   2.0  26.0           111.0        198.0           99.0        72.0
# 1   8.0  24.0           121.0        199.0          103.0        75.0
# 2  81.0  27.0           147.0        203.0          100.0        74.0
# 3  25.0  21.0           150.0        199.0          102.0        70.0
# 4  24.0  26.0           146.0        202.0           99.0        76.0
#
#    Sleep_Hours  Exercise_Hours  Water_Intake  Stress_Level  ...  Diet  \
# 0          4.0             1.0           5.0           5.0  ...     1
# 1          2.0             1.0           2.0           9.0  ...     1
# 2         10.0            -0.0           5.0           1.0  ...     2
# 3          7.0             3.0           3.0           3.0  ...     1
# 4         10.0             2.0           5.0           1.0  ...     2
#
#    MentalHealth  PhysicalActivity  MedicalHistory  Allergies  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
nova_df["Diet_Type__Vegan"]=le.fit_transform(nova_df["Diet_Type__Vegan"])
nova_df["Diet_Type__Vegetarian"]=le.fit_transform(nova_df["Diet_Type__Vegetarian"])
nova_df["Blood_Group_AB"]=le.fit_transform(nova_df["Blood_Group_AB"])
nova_df["Blood_Group_B"]=le.fit_transform(nova_df["Blood_Group_B"])
nova_df["Blood_Group_O"]=le.fit_transform(nova_df["Blood_Group_O"])

# %%
x=nova_df.drop(["Target"],axis=1)
y=nova_df["Target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
lr=LogisticRegression(solver="liblinear")
svc=SVC()
dtc=DecisionTreeClassifier()

# %%
voting_clf=VotingClassifier(
    estimators=[
        ("lr",lr),
        ("svc",svc),
        ("dtc",dtc)
    ])

# %%
voting_clf.fit(x_train,y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(solver='liblinear')),
#                              ('svc', SVC()),
#                              ('dtc', DecisionTreeClassifier())])

# %%
y_pred=voting_clf.predict(x_test)

# %%
print("accuracY:",accuracy_score(y_test,y_pred))
print("classification_report:",classification_report(y_test,y_pred))
# Out:
# accuracY: 0.8436300174520069
# classification_report:               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84      1356
#            1       0.88      0.81      0.85      1509
#
#     accuracy                           0.84      2865
#    macro avg       0.84      0.85      0.84      2865
# weighted avg       0.85      0.84      0.84      2865

# %%
#Stacking
from sklearn.ensemble import StackingClassifier
meta_model=LogisticRegression()
stacking_clf=StackingClassifier(
    estimators=[
        ("lr",lr),
        ("svc",svc),
        ("dtc",dtc)
    ],
    final_estimator=meta_model,
    cv=5
)

# %%
stacking_clf.fit(x_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('lr', LogisticRegression(solver='liblinear')),
#                                ('svc', SVC()),
#                                ('dtc', DecisionTreeClassifier())],
#                    final_estimator=LogisticRegression())

# %%
y_pred=stacking_clf.predict(x_test)
print("accuracy_score",accuracy_score(y_test,y_pred))
# Out:
# accuracy_score 0.9033158813263525
